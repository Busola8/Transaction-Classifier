# %% [markdown]
# # Transaction Classifier Notebook\nThis notebook documents the training flow. Run `python training/train_model.py` to train.

# %%
# Quick check\nimport pandas as pd\ndf = pd.read_csv('data/transactions.csv')\ndf.head()
